# %%
from rdkit import Chem
from rdkit.Chem import PandasTools
import mols2grid
from sigma import SigmaCalculator

# %% [markdown]
# Read the lindanes as 3D structures from and SD file

# %%
df = PandasTools.LoadSDF("lindanes.sdf")

# %% [markdown]
# View the 3D structures

# %%
mols2grid.display(df,mol_col="ROMol",n_cols=4,selection=False)
# Out:
# <script>
#     function fit_height(obj) {
#         obj.style.height = 0;
#         var height = obj.contentDocument.body.scrollHeight + 18 + 'px';
#         obj.style.height = height;
#     }
# </script>
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
# height="200"
#
#
# allow="clipboard-write"
#
# srcdoc="&lt;html&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;head&gt;
#     &lt;style&gt;
#     #mols2grid.gridcontainer {
#     display: block;
#     padding-left: 1em;
#     max-width: 656px;
#     width: 656px;
# }
# #mols2grid .cell {
#     border: 1px solid #cccccc;
#     text-align: center;
#     vertical-align: top;
#     max-width: 160px;
#     width: 160px;
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: 12pt;
#     padding: 0;
#     margin: 0px;
#     float: left;
# }
# #mols2grid .cell:hover {
#     background-color: #e7e7e7 !important;
# }
# #mols2grid .cell .data-img {
#     padding: 0;
#     margin: 0;
# }
# ...

# %% [markdown]
# Assign stereochemistry from the 3D structures

# %%
df.ROMol.apply(Chem.AssignStereochemistryFrom3D)
df['SMILES'] = df.ROMol.apply(Chem.MolToSmiles)

# %% [markdown]
# Display the 2D structures

# %%
cols = [x for x in df.columns if x != 'ROMol']
mols2grid.display(df[cols],subset=["img","ID"],n_cols=4,selection=False)
# Out:
# <script>
#     function fit_height(obj) {
#         obj.style.height = 0;
#         var height = obj.contentDocument.body.scrollHeight + 18 + 'px';
#         obj.style.height = height;
#     }
# </script>
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
# height="200"
#
#
# allow="clipboard-write"
#
# srcdoc="&lt;html&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;head&gt;
#     &lt;style&gt;
#     #mols2grid.gridcontainer {
#     display: block;
#     padding-left: 1em;
#     max-width: 656px;
#     width: 656px;
# }
# #mols2grid .cell {
#     border: 1px solid #cccccc;
#     text-align: center;
#     vertical-align: top;
#     max-width: 160px;
#     width: 160px;
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: 12pt;
#     padding: 0;
#     margin: 0px;
#     float: left;
# }
# #mols2grid .cell:hover {
#     background-color: #e7e7e7 !important;
# }
# #mols2grid .cell .data-img {
#     padding: 0;
#     margin: 0;
# }
# ...

# %%
sigma_calculator = SigmaCalculator()

# %% [markdown]
# Define a 2D molecule for display

# %%
df['mol'] = df.SMILES.apply(Chem.MolFromSmiles)

# %% [markdown]
# Calculate sigma

# %%
df['sigma'] = df.mol.apply(sigma_calculator.calc_sigma_new)

# %% [markdown]
# Display molecules with the name and sigma values below each structure

# %%
cols = [x for x in df.columns if x != 'ROMol']
mols2grid.display(df[cols],subset=["img","ID","sigma"],n_cols=4,selection=False)
# Out:
# <script>
#     function fit_height(obj) {
#         obj.style.height = 0;
#         var height = obj.contentDocument.body.scrollHeight + 18 + 'px';
#         obj.style.height = height;
#     }
# </script>
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
# height="200"
#
#
# allow="clipboard-write"
#
# srcdoc="&lt;html&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;head&gt;
#     &lt;style&gt;
#     #mols2grid.gridcontainer {
#     display: block;
#     padding-left: 1em;
#     max-width: 656px;
#     width: 656px;
# }
# #mols2grid .cell {
#     border: 1px solid #cccccc;
#     text-align: center;
#     vertical-align: top;
#     max-width: 160px;
#     width: 160px;
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: 12pt;
#     padding: 0;
#     margin: 0px;
#     float: left;
# }
# #mols2grid .cell:hover {
#     background-color: #e7e7e7 !important;
# }
# #mols2grid .cell .data-img {
#     padding: 0;
#     margin: 0;
# }
# ...
